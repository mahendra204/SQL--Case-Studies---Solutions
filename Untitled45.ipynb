# %%
import pandas as pd

# Google Sheets file ID
sheet_id = "1SEIzYGdGSc5ChfpadsA9bU8mYrA7WSq-oMsGaGClRRE"

# GID of the sheet tab you want to read (from the URL)
gid = "0"

# Construct the CSV export URL
csv_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"

# Read the sheet into a DataFrame
df = pd.read_csv(csv_url)

# Display the DataFrame
print(df)
# Out:
#           Date                                            Details  \
# 0   28/08/2025                                       Intro + task
# 1    29/8/2025                                  task + scrum call
# 2     2/9/2025                                             tasks
# 3     5/9/2025                                 scrum call + Tasks
# 4     7/9/2025                                             tasks
# 5     9/9/2025                               A Quick Call + Tasks
# 6    11/9/2025  Scrum Calls 2 + Category A Report Generation +...
# 7    12/9/2025                Scrum Calls + Tasks on Cat A, Cat B
# 8    13/9/2025  Tasks on Category A - Country Report - Contact...
# 9   14/09/2025               Scrum Call + Tasks on updates + KPIs
# 10  15/09/2025                            Tasks on updates + KPIs
# 11  18/09/2025                   Scrum Calls + Data Updation Task
# 12  19/09/2025  Tasks on updates with Matrix, CoE Response Due...
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Step 1: Read Google Sheet as CSV
sheet_id = "1SEIzYGdGSc5ChfpadsA9bU8mYrA7WSq-oMsGaGClRRE"
gid = "0"
csv_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
df = pd.read_csv(csv_url)

# Step 2: Define SQL Server connection
server = r'DESKTOP-DVCTLQ2\SQLEXPRESS'  # Use raw string or escape backslash
database = 'meanlifestudies'
username = 'mahendra204'
password = '9441766728'
driver = 'ODBC Driver 17 for SQL Server'

# Step 3: Create SQLAlchemy engine
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver}"
engine = create_engine(connection_string)

# Step 4: Push DataFrame to SQL Server
df.to_sql('crypto_prices', engine, if_exists='replace', index=False)
print("✅ Data successfully loaded to SQL Server!")
# Out:
# ✅ Data successfully loaded to SQL Server!

# %%
import pandas as pd
from sqlalchemy import create_engine

# Step 1: Define SQL Server connection
server = r'DESKTOP-DVCTLQ2\SQLEXPRESS'  # Use raw string or escape backslash
database = 'meanlifestudies'
username = 'mahendra204'
password = '9441766728'
driver = 'ODBC Driver 17 for SQL Server'

# Step 2: Create SQLAlchemy engine
connection_string = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver={driver}"
engine = create_engine(connection_string)

# Step 3: Read data from SQL Server table
query = "SELECT * FROM customers"
df = pd.read_sql(query, engine)

# Step 4: Display the DataFrame
print(df.head())
# Out:
#    id         name                   mai_id
# 0   1     mahendra     mahendra@example.com
# 1   2         mahi         mahi@example.com
# 2   3       ganesh       ganesh@example.com
# 3   4  vivekananda  vivekananda@example.com
# 4   5        sobha        sobha@example.com

# %%
df1 = pd.read_sql('select * from matches', engine)

# %%
df1
# Out:
#    id team1 team2 match_result
# 0   1   CSK   RCB        team2
# 1   2    MI   SRH        team2
# 2   3   KKR   CSK        team1
# 3   4   RCB   LSG        team1
# 4   5    GT    MI         draw
# 5   6   SRH   LSG        team2
# 6   7   LSG    GT        team1
# 7   8    MI   SRH         draw
# 8   9  PJSK   RCB        team2

# %%
df1.to_csv('Desktop/abc.csv', index=False)
